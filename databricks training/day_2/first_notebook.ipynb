# %%
print("Hello!")

# %%
# %sql
create database if not exists first_database;
create table first_database.first_table (id int, name string);
insert into first_database.first_table values (1, 'John'), (2,'Isiah'), (3,'Moses'), (4,'Cain'), (5,'Abel'), (6,'Seth');

select * from first_database.first_table
